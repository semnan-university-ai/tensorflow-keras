# %% [markdown]
# <a href="https://colab.research.google.com/github/semnan-university-ai/tensorflow-keras/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fully connected example

# %% [markdown]
# ![fc.png](data:image/png;base64,...)

# %% [markdown]
# ## **3 ways to create a Machine Learning model with Keras and TensorFlow 2.0 (Sequential, Functional, and Model Subclassing)**
#
#
#
# 1.   Sequential Model is the easiest way to get up and running with Keras in TensorFlow 2.0
# 2.   Functional API is for more complex models, in particular model with multiple inputs or outputs.
# 3.   Model Subclassing is fully-customizable and enables us to implement our own custom forward-pass of the model

# %%
# !pip install mnist
# Out:
# Collecting mnist
#   Downloading https://files.pythonhosted.org/packages/c6/c4/5db3bfe009f8d71f1d532bbadbd0ec203764bba3a469e4703a889db8e5e0/mnist-0.2.2-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from mnist) (1.19.4)
# Installing collected packages: mnist
# Successfully installed mnist-0.2.2

# %%
import numpy as np
import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()

# Normalize the images.
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

# Flatten the images.
train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

# Build the model.
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])

# Compile the model.
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)
# Train the model.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=70,
  batch_size=32,
)
# Out:
# Epoch 1/70
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.5792 - accuracy: 0.8248
# Epoch 2/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2055 - accuracy: 0.9389
# Epoch 3/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1470 - accuracy: 0.9557
# Epoch 4/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1198 - accuracy: 0.9622
# Epoch 5/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1067 - accuracy: 0.9672
# Epoch 6/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0924 - accuracy: 0.9703
# Epoch 7/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0865 - accuracy: 0.9716
# Epoch 8/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0784 - accuracy: 0.9745
# Epoch 9/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0708 - accuracy: 0.9764
# Epoch 10/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0630 - accuracy: 0.9800
# Epoch 11/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0592 - accuracy: 0.9813
# Epoch 12/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0545 - accuracy: 0.9817
# Epoch 13/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0530 - accuracy: 0.9828
# Epoch 14/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0485 - accuracy: 0.9840
# Epoch 15/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0453 - accuracy: 0.9842
# Epoch 16/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0433 - accuracy: 0.9851
# Epoch 17/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0436 - accuracy: 0.9855
# Epoch 18/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0393 - accuracy: 0.9864
# Epoch 19/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0378 - accuracy: 0.9875
# Epoch 20/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0336 - accuracy: 0.9883
# Epoch 21/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0356 - accuracy: 0.9889
# Epoch 22/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0323 - accuracy: 0.9891
# Epoch 23/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0332 - accuracy: 0.9878
# Epoch 24/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0322 - accuracy: 0.9893
# Epoch 25/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0309 - accuracy: 0.9896
# Epoch 26/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0296 - accuracy: 0.9895
# Epoch 27/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0298 - accuracy: 0.9898
# Epoch 28/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0264 - accuracy: 0.9911
# Epoch 29/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0287 - accuracy: 0.9901
# Epoch 30/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0238 - accuracy: 0.9917
# Epoch 31/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0243 - accuracy: 0.9909
# Epoch 32/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0234 - accuracy: 0.9917
# Epoch 33/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0198 - accuracy: 0.9934
# Epoch 34/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0239 - accuracy: 0.9920
# Epoch 35/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0243 - accuracy: 0.9910
# Epoch 36/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0231 - accuracy: 0.9926
# Epoch 37/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0221 - accuracy: 0.9926
# Epoch 38/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0210 - accuracy: 0.9930
# Epoch 39/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0185 - accuracy: 0.9937
# Epoch 40/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0212 - accuracy: 0.9928
# Epoch 41/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0178 - accuracy: 0.9938
# Epoch 42/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0202 - accuracy: 0.9933
# Epoch 43/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0181 - accuracy: 0.9941
# Epoch 44/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0186 - accuracy: 0.9939
# Epoch 45/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0204 - accuracy: 0.9928
# Epoch 46/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0203 - accuracy: 0.9938
# Epoch 47/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0202 - accuracy: 0.9930
# Epoch 48/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9941
# Epoch 49/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946
# Epoch 50/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0179 - accuracy: 0.9939
# Epoch 51/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0187 - accuracy: 0.9942
# Epoch 52/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0187 - accuracy: 0.9938
# Epoch 53/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0185 - accuracy: 0.9938
# Epoch 54/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0175 - accuracy: 0.9943
# Epoch 55/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0191 - accuracy: 0.9937
# Epoch 56/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0197 - accuracy: 0.9938
# Epoch 57/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0149 - accuracy: 0.9951
# Epoch 58/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0162 - accuracy: 0.9947
# Epoch 59/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9942
# Epoch 60/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0163 - accuracy: 0.9948
# Epoch 61/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0162 - accuracy: 0.9943
# Epoch 62/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0178 - accuracy: 0.9940
# Epoch 63/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0149 - accuracy: 0.9949
# Epoch 64/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0161 - accuracy: 0.9945
# Epoch 65/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9951
# Epoch 66/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9951
# Epoch 67/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0144 - accuracy: 0.9954
# Epoch 68/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0146 - accuracy: 0.9950
# Epoch 69/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0143 - accuracy: 0.9955
# Epoch 70/70
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0131 - accuracy: 0.9955

# %%
model.evaluate(
  test_images,
  to_categorical(test_labels)
)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2023 - accuracy: 0.9720
# [0.20229823887348175, 0.972000002861023]

# %%
model.save_weights('model.h5')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Build the model.
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])

# Load the model's saved weights.
model.load_weights('model.h5')

# %%
# Predict on the first 5 test images.
predictions = model.predict(test_images[:20])

# Print our model's predictions.
print(np.argmax(predictions, axis=1)) # [7, 2, 1, 0, 4]

# Check our predictions against the ground truths.
print(test_labels[:20]) # [7, 2, 1, 0, 4]
# Out:
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 8 4]
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]

# %%
import numpy as np
import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()

# Normalize the images.
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

# Flatten the images.
train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

# Build the model.
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),#sigmoid
  # Dropout(0.5),
  Dense(64, activation='relu'),#sigmoid
  # Dropout(0.5),   
  Dense(64, activation='relu'),#sigmoid
  Dense(10, activation='softmax'),
])

# Compile the model.
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# Train the model.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=5,
  batch_size=32,
  validation_data=(test_images, to_categorical(test_labels))

)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6071 - accuracy: 0.8067 - val_loss: 0.2512 - val_accuracy: 0.9205
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1870 - accuracy: 0.9443 - val_loss: 0.1495 - val_accuracy: 0.9544
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1459 - accuracy: 0.9550 - val_loss: 0.1273 - val_accuracy: 0.9598
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1293 - accuracy: 0.9604 - val_loss: 0.1131 - val_accuracy: 0.9634
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1120 - accuracy: 0.9644 - val_loss: 0.1275 - val_accuracy: 0.9612
